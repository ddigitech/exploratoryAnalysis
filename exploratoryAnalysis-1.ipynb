# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBacked.figure_format ='png'

pd.set_option("display.precision", 2)

df = pd.read_csv("/Users/dhende63/Downloads/Queue Depth-data-as-seriestocolumns-2021-03-25 13_53_04.csv")
#df.head()

#print(df.shape)
#print(df.columns)
#print(df.info())




df.apply(np.max)

#sns.countplot(x="Time", hue="QDEPTH: HIE.CONN_ADT_A01_TOPIC_DEST, WMQC136", data=df);

#features = ["Time", "QDEPTH: HIE.CONN_ADT_A01_TOPIC_DEST, WMQC136"]
#df[features].hist(figsize=(10,4));

#sns.jointplot(x="Time", y="QDEPTH: HIE.CONN_ADT_A01_TOPIC_DEST, WMQC136", data=df, kind="scatter");

#sns.displot(df["QDEPTH: HIE.CONN_ADT_A01_TOPIC_DEST, WMQC136"]);

#sns.boxplot(x="QDEPTH: HIE.CONN_ADT_A01_TOPIC_DEST, WMQC136", data=df);



df.describe()

#df[features].describe()
#df["Time"] = df["Time"].astype("int64")

#pd.crosstab(df)


#sns.pairplot(df);
# Out:
#        QDEPTH: HIE.CDM_PSA_UPDATE_TOPIC_DEST, WMQC136  \
# count                                          705.00
# mean                                         60808.69
# std                                          79167.93
# min                                              0.00
# 25%                                              0.00
# 50%                                             11.00
# 75%                                         134682.00
# max                                         200002.00
#
#        QDEPTH: HIE.CONN_ADT_A01_TOPIC_DEST, WMQC136  \
# count                                        705.00
# mean                                         468.88
# std                                         1004.78
# min                                            0.00
# 25%                                            0.00
# 50%                                            0.00
# 75%                                          358.00
# max                                         3955.00
#
#        QDEPTH: HIE.CONN_ADT_A08_TOPIC_DEST, WMQC136  \
# count                                        705.00
# mean                                           0.09
# std                                            0.32
# min                                            0.00
# 25%                                            0.00
# 50%                                            0.00
# 75%                                            0.00
# max                                            2.00
#
#        QDEPTH: HIE.CONN_HL7V2_OUTBOUND, WMQC136  \
# count                                    705.00
# mean                                       4.11
# std                                        5.36
# min                                        0.00
# 25%                                        0.00
# 50%                                        1.00
# 75%                                        8.00
# max                                       22.00
#
#        QDEPTH: HIE.CONN_ORU_R01_LAB_TOPIC_DEST, WMQC136  \
# count                                            705.00
# mean                                             330.96
# std                                              899.79
# min                                                0.00
# 25%                                                0.00
# 50%                                                0.00
# 75%                                                2.00
# max                                             3723.00
#
#        QDEPTH: HIE.CONN_V2_TENANT_SPECIFIC_1, WMQC136  \
# count                                          705.00
# mean                                           246.07
# std                                            722.27
# min                                              0.00
# 25%                                              0.00
# 50%                                              0.00
# 75%                                             25.00
# max                                           3653.00
#
#        QDEPTH: HIE.CONN_V2_TENANT_SPECIFIC_2, WMQC136  \
# count                                          705.00
# mean                                         65322.55
# std                                          88637.65
# min                                              0.00
# 25%                                              0.00
# 50%                                             54.00
# 75%                                         138625.00
# max                                         236665.00
#
#        QDEPTH: HIE.CONN_XDR_TENANT_SPECIFIC_1, WMQC136  \
# count                                           705.00
# mean                                           4403.34
# std                                            6167.69
# min                                               0.00
# 25%                                               0.00
# 50%                                               0.00
# 75%                                            9201.00
# max                                           17164.00
#
#        QDEPTH: HIE.CONN_XDR_TENANT_SPECIFIC_2, WMQC136  \
# count                                            705.0
# mean                                               0.0
# std                                                0.0
# min                                                0.0
# 25%                                                0.0
# 50%                                                0.0
# 75%                                                0.0
# max                                                0.0
#
#        QDEPTH: HIE.CS_AUDIT_QUEUE, WMQC136  QDEPTH: HIE.PES_QUEUE_1, WMQC136  \
# count                               705.00                            705.00
# mean                              76034.27                           8423.39
# std                              102571.86                          10875.98
# min                                   0.00                              0.00
# 25%                                   0.00                              0.00
# 50%                                   7.00                            103.00
# 75%                              171646.00                          17709.00
# max                              280659.00                          30381.00
#
#        QDEPTH: HIE.PES_QUEUE_2, WMQC136  QDEPTH: HIE.PES_QUEUE_3, WMQC136  \
# count                            705.00                            705.00
# mean                               0.39                           9353.14
# std                                0.91                          12718.51
# min                                0.00                              0.00
# 25%                                0.00                              0.00
# 50%                                0.00                              0.00
# 75%                                0.00                          21027.00
# max                                8.00                          35503.00
#
#        QDEPTH: HIE.STG1.CONN_TOPIC_ORU_R01_LAB_CALCOVID, WMQC136
# count                                             705.00
# mean                                                0.52
# std                                                 1.22
# min                                                 0.00
# 25%                                                 0.00
# 50%                                                 0.00
# 75%                                                 1.00
# max                                                10.00
